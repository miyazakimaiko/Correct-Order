# %%
import pandas as pd
import os

# %%
files = [file for file in os.listdir('daily_sales_csv')]

all_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("daily_sales_csv/"+file, delimiter=';')
    all_data = pd.concat([all_data, df])
        
all_data[['Catalog Number', 'Purchased', 'Returned', 'Sold', 'Wasted']]
    
# all_data.to_csv("all_data.csv", index=False)
# Out:
# /Users/MAIKO/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys
#     Catalog Number  Purchased  Returned     Sold  Wasted
# 0              NaN      105.0       0.0  47.3650     0.0
# 1         HC-CROIS        0.0       0.0   3.0000     1.0
# 2     BUTTER-CROIS        0.0       0.0   3.0000     9.0
# 3   RASP-JAM-3.5KG        0.0       0.0   0.1214     0.0
# 4         HONEY-1L        0.0       0.0   0.0300     0.0
# ..             ...        ...       ...      ...     ...
# 28       COND-MILK        0.0       0.0   0.0441     0.0
# 29        PORR-TOP        0.0       0.0   0.0000     0.0
# 30         FAL-WRP        0.0       0.0   0.0000     0.0
# 31        HONEY-1L        0.0       0.0   0.0000     0.0
# 32       PORR-OATS        0.0       0.0   0.0000     0.0
#
# [1257 rows x 5 columns]
