# %%
import os
import sys
import pandas as pd

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from functions import get_dates, get_accesstoken

# %%
from talech_keys import grant_type, client_id_1, client_id_2, client_secret_1, client_secret_2, \
    client_version, token_url, refresh_token_1, refresh_token_2, ID_HQ, ID_IFSC, ID_PSL, ID_SAS, ID_TCD

# %%
accesstoken = get_accesstoken(client_id_1, client_secret_1, refresh_token_1, client_version, token_url)

# %%
token = {
    'securityToken': accesstoken,
    'X-POS-MerchantId': ID_SAS
}

# %%
import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import calendar

def get_months_dates(month, year):
    # This returns list of dates of specified lengths of months.
    lst = []
    for i in range(-7, calendar.monthlen(year, month)): 
        date_ = datetime.date(year, month, 1)
        date = date_ + datetime.timedelta(days=i)
        lst.append(date.strftime("%m/%d/%Y 00:00:00"))
    return lst

# %%
month = 7
year = 2019
days = get_months_dates(month, year)

# %%
print(days)
# Out:
# ['06/24/2019 00:00:00', '06/25/2019 00:00:00', '06/26/2019 00:00:00', '06/27/2019 00:00:00', '06/28/2019 00:00:00', '06/29/2019 00:00:00', '06/30/2019 00:00:00', '07/01/2019 00:00:00', '07/02/2019 00:00:00', '07/03/2019 00:00:00', '07/04/2019 00:00:00', '07/05/2019 00:00:00', '07/06/2019 00:00:00', '07/07/2019 00:00:00', '07/08/2019 00:00:00', '07/09/2019 00:00:00', '07/10/2019 00:00:00', '07/11/2019 00:00:00', '07/12/2019 00:00:00', '07/13/2019 00:00:00', '07/14/2019 00:00:00', '07/15/2019 00:00:00', '07/16/2019 00:00:00', '07/17/2019 00:00:00', '07/18/2019 00:00:00', '07/19/2019 00:00:00', '07/20/2019 00:00:00', '07/21/2019 00:00:00', '07/22/2019 00:00:00', '07/23/2019 00:00:00', '07/24/2019 00:00:00', '07/25/2019 00:00:00', '07/26/2019 00:00:00', '07/27/2019 00:00:00', '07/28/2019 00:00:00', '07/29/2019 00:00:00', '07/30/2019 00:00:00', '07/31/2019 00:00:00']

# %%
import datetime
import requests

# %%
def json_get_sales_count(obj):
    """Recursively fetch values from nested JSON."""
    arr = {'bakedgoods': {}, 'breakfast': {}, 'lunch': {}}
    itemvalue = None
    categoryname = None
    itemname = None

    def extract(obj, arr, itemvalue, categoryname, itemname):
        """Recursively search for values of key in JSON tree."""
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, (dict, list)):
                    extract(v, arr, itemvalue, categoryname, itemname)
                elif k == 'item':
                    itemkey = v
                elif k == 'soldQuantity':
                    itemvalue = v
                elif k == 'categoryName':
                    if v == 'LUNCH':
                        categoryname = 'lunch'
                    elif v == 'BREAKFAST':
                        categoryname = 'breakfast'
                    elif v == 'BAKED GOODS':
                        categoryname = 'bakedgoods'
                elif k == 'productName':
                    v = v.replace(' + ', '')
                    v = v.replace('To Go', '')
                    v = v.replace('Sit In', '')
                    v = v.replace('/w Mixed Seeds, Nuts & Honey', '')
                    v = v.replace('/w Cranberries, Hazelnuts & Honey', '')
                    v = v.replace('/w Honey', '')
                    v = v.replace(', ', '')
                    v = v.replace('Not Heated', '')
                    v = v.replace('Heated', '')
                    v = v.replace('Soup & Sandwich', '')
                    v = v.replace('Ham Toastie', 'Ham & Cheese Toastie')
                    itemname = v

                if categoryname and itemvalue and itemname:
                    if itemname in arr[categoryname]:
                        arr[categoryname][itemname] += itemvalue
                    else:
                        arr[categoryname][itemname] = itemvalue
                    itemvalue = None
                    categoryname = None
                    itemname = None

        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, itemvalue, categoryname, itemname)
        return arr

    values = extract(obj, arr, itemvalue, categoryname, itemname)
    return values

# %%
def get_summary_report(token, startdate, enddate):
    arr = {
        'searchCriteria': {
            'startDate': startdate,
            'endDate': enddate,
            'includedReports': [102]
        }
    }
    result = requests.post(url='https://mapi-eu.talech.com/reports/receiptssummaryreport',
                           json=arr,
                           headers=token)
    items = result.json()
    salesdata = json_get_sales_count(items)
    return salesdata
    return items

# %%
dailysales = {}
for i in range(0, len(days)):
    d = pd.to_datetime(days[i])
    end = str(d.replace(hour=23).strftime('%m/%d/%Y %H:%M:%S'))
    salesdata = get_summary_report(token, days[i], end)
    dailysales[days[i]] = salesdata

# %%
dailysales
# Out:
# {'06/24/2019 00:00:00': {'bakedgoods': {'Cinnabun': 7,
#    'Salted Caramel Brownie': 4,
#    'Oatmeal & Raisin Cookie': 4,
#    'Pain au Chocolat': 4,
#    'Croissant': 3,
#    'Mixed Berry Scone': 18,
#    'Granola Bar': 4,
#    'Blueberry Banana Loaf': 9,
#    'Custard Tart': 3,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 8,
#    'Pain au Raisin': 3,
#    'Snickers Boost Ball': 5},
#   'breakfast': {'Ham Cheese Croissant': 3,
#    'Sourdough Toast': 3,
#    'Sausage Roll': 1,
#    'Organic Porridge': 7,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Tuna Melt': 3,
#    'Caprese': 2,
#    'Ham & Cheese Toastie': 1,
#    'Chicken Bacon Wrap': 4}},
#  '06/25/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Pain au Chocolat': 2,
#    'Croissant': 7,
#    'Mixed Berry Scone': 18,
#    'Custard Tart': 5,
#    'Oatmeal & Raisin Cookie': 1,
#    'Granola Bar': 5,
#    'Blueberry Banana Loaf': 6,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 11,
#    'Pain au Raisin': 5,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Sausage Roll': 2,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 3,
#    'Ham Cheese Croissant': 2},
#   'lunch': {'Spring Vegan Wrap': 2,
#    'Ham & Cheese Toastie': 5,
#    'Caprese': 3,
#    'Chicken Bacon Wrap': 3,
#    'Tuna Melt': 1,
#    'Chicken & Stuffing Bap': 2}},
#  '06/26/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 15,
#    'Cinnabun': 4,
#    'Salted Caramel Brownie': 4,
#    'Oatmeal & Raisin Cookie': 4,
#    'Pain au Chocolat': 2,
#    'Croissant': 4,
#    'Granola Bar': 4,
#    'Blueberry Banana Loaf': 5,
#    'Custard Tart': 5,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 6,
#    'Pain au Raisin': 4,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Sourdough Toast': 1,
#    'Sausage Roll': 5,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Caprese': 2,
#    'Ham & Cheese Toastie': 3,
#    'Tuna Melt': 2,
#    'Chicken Bacon Wrap': 4,
#    'Spring Wrap': 1,
#    'Chicken & Stuffing Bap': 2}},
#  '06/27/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Pain au Chocolat': 2,
#    'Croissant': 4,
#    'Salted Caramel Brownie': 1,
#    'Mixed Berry Scone': 16,
#    'Custard Tart': 6,
#    'Oatmeal & Raisin Cookie': 2,
#    'Granola Bar': 4,
#    'Apple & Pistachio Financier': 6,
#    'Anzac Biscuit': 11,
#    'Blueberry Banana Loaf': 6,
#    'Pain au Raisin': 6,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Ham Cheese Croissant': 4,
#    'Sausage Roll': 6,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 6},
#   'lunch': {'Spring Vegan Wrap': 2,
#    'Tuna Melt': 2,
#    'Caprese': 5,
#    'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 4,
#    'Chicken & Stuffing Bap': 2}},
#  '06/28/2019 00:00:00': {'bakedgoods': {'Cinnabun': 7,
#    'Salted Caramel Brownie': 2,
#    'Pain au Chocolat': 5,
#    'Croissant': 7,
#    'Mixed Berry Scone': 15,
#    'Custard Tart': 6,
#    'Oatmeal & Raisin Cookie': 3,
#    'Granola Bar': 4,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 11,
#    'Snickers Boost Ball': 7,
#    'Pain au Raisin': 6},
#   'breakfast': {'Sausage Roll': 6,
#    'Organic Porridge': 3,
#    'Berry & Granola Parfait': 4,
#    'Ham Cheese Croissant': 2},
#   'lunch': {'Caprese': 4,
#    'Ham & Cheese Toastie': 4,
#    'Chicken Bacon Wrap': 3,
#    'Chicken & Stuffing Bap': 2,
#    'Tuna Melt': 1}},
#  '06/29/2019 00:00:00': {'bakedgoods': {'Cinnabun': 5,
#    'Pain au Chocolat': 1,
#    'Salted Caramel Brownie': 7,
#    'Croissant': 4,
#    'Mixed Berry Scone': 8,
#    'Custard Tart': 7,
#    'Oatmeal & Raisin Cookie': 4,
#    'Blueberry Banana Loaf': 4,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 2,
#    'Snickers Boost Ball': 5,
#    'Pain au Raisin': 5,
#    'Granola Bar': 3},
#   'breakfast': {'Berry & Granola Parfait': 2, 'Sausage Roll': 6},
#   'lunch': {'Spring Vegan Wrap': 3,
#    'Tuna Melt': 3,
#    'Ham & Cheese Toastie': 3,
#    'Chicken Bacon Wrap': 2,
#    'Caprese': 2,
#    'Chicken & Stuffing Bap': 2}},
#  '06/30/2019 00:00:00': {'bakedgoods': {'Cinnabun': 4,
#    'Pain au Chocolat': 4,
#    'Salted Caramel Brownie': 4,
#    'Croissant': 2,
#    'Custard Tart': 4,
#    'Oatmeal & Raisin Cookie': 1,
#    'Granola Bar': 1,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 7,
#    'Snickers Boost Ball': 4,
#    'Pain au Raisin': 1,
#    'Mixed Berry Scone': 8},
#   'breakfast': {'Ham Cheese Croissant': 3,
#    'Sausage Roll': 4,
#    'Berry & Granola Parfait': 2,
#    'Cheese Croissant': 1},
#   'lunch': {'Caprese': 2,
#    'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 2,
#    'Chicken & Stuffing Bap': 1}},
#  '07/01/2019 00:00:00': {'bakedgoods': {'Cinnabun': 4,
#    'Oatmeal & Raisin Cookie': 4,
#    'Pain au Chocolat': 2,
#    'Croissant': 6,
#    'Salted Caramel Brownie': 1,
#    'Mixed Berry Scone': 13,
#    'Blueberry Banana Loaf': 4,
#    'Custard Tart': 3,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 12,
#    'Snickers Boost Ball': 6,
#    'Pain au Raisin': 6,
#    'Granola Bar': 5},
#   'breakfast': {'Ham Cheese Croissant': 2,
#    'Sourdough Toast': 1,
#    'Organic Porridge': 6,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Ham & Cheese Toastie': 4,
#    'Caprese': 1,
#    'Tuna Melt': 1,
#    'Chicken Bacon Wrap': 2,
#    'Spring Vegan Wrap': 1,
#    'Chicken & Stuffing Bap': 1,
#    'Chicken Stuffing': 1}},
#  '07/02/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Salted Caramel Brownie': 5,
#    'Oatmeal & Raisin Cookie': 10,
#    'Pain au Chocolat': 4,
#    'Croissant': 6,
#    'Mixed Berry Scone': 20,
#    'Custard Tart': 7,
#    'Granola Bar': 10,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 6,
#    'Anzac Biscuit': 8,
#    'Pain au Raisin': 4,
#    'Snickers Boost Ball': 7},
#   'breakfast': {'Ham Cheese Croissant': 3,
#    'Sausage Roll': 1,
#    'Organic Porridge': 3,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Caprese': 3,
#    'Ham & Cheese Toastie': 1,
#    'Chicken Stuffing': 2,
#    'Chicken Bacon Wrap': 2,
#    'Soup of the Day': 1,
#    'Spring Vegan Wrap': 1,
#    'Tuna Melt': 2}},
#  '07/03/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 17,
#    'Cinnabun': 6,
#    'Pain au Chocolat': 4,
#    'Salted Caramel Brownie': 3,
#    'Croissant': 6,
#    'Custard Tart': 4,
#    'Oatmeal & Raisin Cookie': 6,
#    'Granola Bar': 5,
#    'Blueberry Banana Loaf': 6,
#    'Apple & Pistachio Financier': 6,
#    'Anzac Biscuit': 10,
#    'Pain au Raisin': 5,
#    'Snickers Boost Ball': 6},
#   'breakfast': {'Sourdough Toast': 1,
#    'Bacon Soda Farl': 2,
#    'Organic Porridge': 3,
#    'Berry & Granola Parfait': 4,
#    'Sausage Roll': 2,
#    'Ham Cheese Croissant': 2},
#   'lunch': {'Tuna Melt': 2,
#    'Ham & Cheese Toastie': 1,
#    'Chicken & Stuffing Bap': 1,
#    'Chicken Bacon Wrap': 3}},
#  '07/04/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 19,
#    'Cinnabun': 9,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 4,
#    'Croissant': 6,
#    'Custard Tart': 8,
#    'Oatmeal & Raisin Cookie': 5,
#    'Apple & Pistachio Financier': 6,
#    'Anzac Biscuit': 10,
#    'Snickers Boost Ball': 7,
#    'Blueberry Banana Loaf': 7,
#    'Pain au Raisin': 6,
#    'Granola Bar': 4},
#   'breakfast': {'Bacon Soda Farl': 1,
#    'Sausage Roll': 3,
#    'Berry & Granola Parfait': 4,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Caprese': 2,
#    'Spring Vegan Wrap': 1,
#    'Chicken & Stuffing Bap': 3,
#    'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 4,
#    'Tuna Melt': 2}},
#  '07/05/2019 00:00:00': {'bakedgoods': {'Croissant': 6,
#    'Salted Caramel Brownie': 4,
#    'Oatmeal & Raisin Cookie': 6,
#    'Custard Tart': 6,
#    'Anzac Biscuit': 7,
#    'Snickers Boost Ball': 6,
#    'Apple & Pistachio Financier': 7,
#    'Mixed Berry Scone': 21,
#    'Pain au Raisin': 6,
#    'Cinnabun': 8,
#    'Pain au Chocolat': 3,
#    'Granola Bar': 6,
#    'Blueberry Banana Loaf': 5},
#   'breakfast': {'Sourdough Toast': 2,
#    'Sausage Roll': 6,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 4,
#    'Ham Cheese Croissant': 3},
#   'lunch': {'Spring Vegan Wrap': 1,
#    'Chicken Bacon Wrap': 3,
#    'Ham & Cheese Toastie': 5,
#    'Soup of the Day': 1,
#    'Caprese': 1,
#    'Tuna Melt': 2,
#    'Chicken & Stuffing Bap': 1}},
#  '07/06/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 12,
#    'Cinnabun': 6,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 6,
#    'Oatmeal & Raisin Cookie': 7,
#    'Custard Tart': 5,
#    'Granola Bar': 4,
#    'Blueberry Banana Loaf': 4,
#    'Apple & Pistachio Financier': 6,
#    'Anzac Biscuit': 7,
#    'Croissant': 4,
#    'Pain au Raisin': 5,
#    'Snickers Boost Ball': 3},
#   'breakfast': {'Bacon Soda Farl': 1,
#    'Berry & Granola Parfait': 2,
#    'Sausage Roll': 3,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Ham & Cheese Toastie': 1,
#    'Chicken & Stuffing Bap': 1,
#    'Caprese': 1}},
#  '07/07/2019 00:00:00': {'bakedgoods': {'Cinnabun': 3,
#    'Oatmeal & Raisin Cookie': 4,
#    'Pain au Chocolat': 2,
#    'Croissant': 2,
#    'Mixed Berry Scone': 9,
#    'Custard Tart': 3,
#    'Granola Bar': 2,
#    'Blueberry Banana Loaf': 2,
#    'Apple & Pistachio Financier': 2,
#    'Anzac Biscuit': 2,
#    'Snickers Boost Ball': 3,
#    'Pain au Raisin': 2},
#   'breakfast': {'Bacon Soda Farl': 2,
#    'Sausage Roll': 1,
#    'Berry & Granola Parfait': 2},
#   'lunch': {'Spring Vegan Wrap': 1,
#    'Chicken Bacon Wrap': 2,
#    'Tuna Melt': 2,
#    'Ham & Cheese Toastie': 2,
#    'Caprese': 1,
#    'Chicken & Stuffing Bap': 1}},
#  '07/08/2019 00:00:00': {'bakedgoods': {'Cinnabun': 5,
#    'Pain au Chocolat': 2,
#    'Salted Caramel Brownie': 3,
#    'Croissant': 6,
#    'Mixed Berry Scone': 15,
#    'Custard Tart': 5,
#    'Oatmeal & Raisin Cookie': 3,
#    'Granola Bar': 5,
#    'Blueberry Banana Loaf': 5,
#    'Anzac Biscuit': 10,
#    'Snickers Boost Ball': 6,
#    'Pain au Raisin': 1},
#   'breakfast': {'Sourdough Toast': 2,
#    'Bacon Soda Farl': 3,
#    'Sausage Roll': 1,
#    'Organic Porridge': 7,
#    'Berry & Granola Parfait': 5,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Tuna Melt': 1,
#    'Caprese': 2,
#    'Ham & Cheese Toastie': 3,
#    'Chicken Stuffing': 1,
#    'Spring Vegan Wrap': 1,
#    'Chicken & Stuffing Bap': 1}},
#  '07/09/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 21,
#    'Cinnabun': 6,
#    'Pain au Chocolat': 4,
#    'Salted Caramel Brownie': 4,
#    'Oatmeal & Raisin Cookie': 1,
#    'Croissant': 5,
#    'Granola Bar': 8,
#    'Blueberry Banana Loaf': 7,
#    'Custard Tart': 3,
#    'Apple & Pistachio Financier': 5,
#    'Anzac Biscuit': 9,
#    'Snickers Boost Ball': 6,
#    'Pain au Raisin': 4},
#   'breakfast': {'Cheese Croissant': 1,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 2,
#    'Organic Porridge': 6,
#    'Berry & Granola Parfait': 5,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Chicken & Stuffing Bap': 2,
#    'Chicken Stuffing': 2,
#    'Tuna Melt': 2,
#    'Chicken Bacon Wrap': 2,
#    'Spring Vegan Wrap': 2,
#    'Ham & Cheese Toastie': 1,
#    'Caprese': 1,
#    'Soup of the Day': 1}},
#  '07/10/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 6,
#    'Oatmeal & Raisin Cookie': 6,
#    'Croissant': 5,
#    'Mixed Berry Scone': 19,
#    'Custard Tart': 9,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 13,
#    'Blueberry Banana Loaf': 5,
#    'Pain au Raisin': 3,
#    'Granola Bar': 4,
#    'Snickers Boost Ball': 8},
#   'breakfast': {'Bacon Soda Farl': 1,
#    'Sausage Roll': 3,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Spring Vegan Wrap': 1,
#    'Ham & Cheese Toastie': 2,
#    'Caprese': 2,
#    'Chicken Bacon Wrap': 4,
#    'Tuna Melt': 1,
#    'Chicken & Stuffing Bap': 4}},
#  '07/11/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 15,
#    'Cinnabun': 5,
#    'Pain au Chocolat': 4,
#    'Salted Caramel Brownie': 5,
#    'Oatmeal & Raisin Cookie': 5,
#    'Croissant': 5,
#    'Custard Tart': 5,
#    'Granola Bar': 3,
#    'Blueberry Banana Loaf': 5,
#    'Anzac Biscuit': 10,
#    'Apple & Pistachio Financier': 6,
#    'Pain au Raisin': 5,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Bacon Soda Farl': 1,
#    'Sausage Roll': 5,
#    'Organic Porridge': 2,
#    'Berry & Granola Parfait': 4,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Spring Vegan Wrap': 3,
#    'Tuna Melt': 2,
#    'Caprese': 4,
#    'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 2,
#    'Spring Wrap': 1,
#    'Chicken & Stuffing Bap': 3}},
#  '07/12/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 23,
#    'Cinnabun': 7,
#    'Pain au Chocolat': 4,
#    'Salted Caramel Brownie': 6,
#    'Croissant': 5,
#    'Oatmeal & Raisin Cookie': 2,
#    'Granola Bar': 8,
#    'Blueberry Banana Loaf': 7,
#    'Custard Tart': 6,
#    'Apple & Pistachio Financier': 5,
#    'Anzac Biscuit': 8,
#    'Pain au Raisin': 5,
#    'Snickers Boost Ball': 6},
#   'breakfast': {'Ham Cheese Croissant': 6,
#    'Sourdough Toast': 4,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 8,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 2,
#    'Chicken & Stuffing Bap': 3,
#    'Tuna Melt': 1,
#    'Soup of the Day': 1}},
#  '07/13/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 6,
#    'Oatmeal & Raisin Cookie': 1,
#    'Croissant': 5,
#    'Mixed Berry Scone': 8,
#    'Blueberry Banana Loaf': 1,
#    'Custard Tart': 2,
#    'Apple & Pistachio Financier': 6,
#    'Anzac Biscuit': 3,
#    'Snickers Boost Ball': 7,
#    'Pain au Raisin': 3,
#    'Granola Bar': 1},
#   'breakfast': {'Ham Cheese Croissant': 2,
#    'Bacon Soda Farl': 2,
#    'Berry & Granola Parfait': 1,
#    'Sausage Roll': 3},
#   'lunch': {'Caprese': 3,
#    'Chicken Bacon Wrap': 4,
#    'Tuna Melt': 1,
#    'Spring Vegan Wrap': 1,
#    'Ham & Cheese Toastie': 2,
#    'Chicken & Stuffing Bap': 2}},
#  '07/14/2019 00:00:00': {'bakedgoods': {'Cinnabun': 5,
#    'Pain au Chocolat': 2,
#    'Croissant': 4,
#    'Salted Caramel Brownie': 2,
#    'Mixed Berry Scone': 5,
#    'Custard Tart': 3,
#    'Oatmeal & Raisin Cookie': 3,
#    'Granola Bar': 1,
#    'Anzac Biscuit': 2,
#    'Apple & Pistachio Financier': 3,
#    'Pain au Raisin': 1,
#    'Snickers Boost Ball': 2},
#   'breakfast': {'Sourdough Toast': 1,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 3,
#    'Berry & Granola Parfait': 2},
#   'lunch': {'Ham & Cheese Toastie': 1, 'Chicken Bacon Wrap': 1, 'Caprese': 1}},
#  '07/15/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 18,
#    'Cinnabun': 6,
#    'Pain au Chocolat': 3,
#    'Croissant': 6,
#    'Salted Caramel Brownie': 2,
#    'Custard Tart': 3,
#    'Oatmeal & Raisin Cookie': 2,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 7,
#    'Anzac Biscuit': 10,
#    'Snickers Boost Ball': 2,
#    'Pain au Raisin': 4,
#    'Granola Bar': 4},
#   'breakfast': {'Ham Cheese Croissant': 4,
#    'Sourdough Toast': 1,
#    'Sausage Roll': 1,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 5},
#   'lunch': {'Spring Vegan Wrap': 2,
#    'Caprese': 3,
#    'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 2,
#    'Tuna Melt': 2,
#    'Soup of the Day': 1,
#    'Chicken & Stuffing Bap': 2}},
#  '07/16/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 14,
#    'Cinnabun': 5,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 4,
#    'Croissant': 4,
#    'Oatmeal & Raisin Cookie': 3,
#    'Granola Bar': 9,
#    'Custard Tart': 2,
#    'Anzac Biscuit': 12,
#    'Snickers Boost Ball': 8,
#    'Blueberry Banana Loaf': 4,
#    'Apple & Pistachio Financier': 6,
#    'Pain au Raisin': 3},
#   'breakfast': {'Bacon Soda Farl': 1,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 4,
#    'Sausage Roll': 1,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Ham & Cheese Toastie': 5,
#    'Chicken Bacon Wrap': 2,
#    'Tuna Melt': 1,
#    'Spring Vegan Wrap': 3,
#    'Chicken & Stuffing Bap': 1,
#    'Caprese': 1}},
#  '07/17/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 19,
#    'Cinnabun': 6,
#    'Pain au Chocolat': 4,
#    'Salted Caramel Brownie': 3,
#    'Oatmeal & Raisin Cookie': 7,
#    'Croissant': 4,
#    'Custard Tart': 8,
#    'Granola Bar': 4,
#    'Anzac Biscuit': 7,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 4,
#    'Pain au Raisin': 4,
#    'Snickers Boost Ball': 7},
#   'breakfast': {'Ham Cheese Croissant': 1,
#    'Sausage Roll': 2,
#    'Organic Porridge': 6,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Tuna Melt': 1,
#    'Chicken Bacon Wrap': 1,
#    'Spring Vegan Wrap': 2,
#    'Chicken & Stuffing Bap': 2,
#    'Caprese': 1}},
#  '07/18/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 22,
#    'Cinnabun': 7,
#    'Salted Caramel Brownie': 3,
#    'Pain au Chocolat': 4,
#    'Croissant': 4,
#    'Custard Tart': 4,
#    'Oatmeal & Raisin Cookie': 4,
#    'Granola Bar': 6,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 8,
#    'Blueberry Banana Loaf': 5,
#    'Pain au Raisin': 4,
#    'Snickers Boost Ball': 5},
#   'breakfast': {'Ham Cheese Croissant': 3,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 1,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Caprese': 3,
#    'Spring Vegan Wrap': 2,
#    'Tuna Melt': 2,
#    'Chicken Bacon Wrap': 2,
#    'Ham & Cheese Toastie': 3}},
#  '07/19/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 21,
#    'Cinnabun': 6,
#    'Salted Caramel Brownie': 3,
#    'Oatmeal & Raisin Cookie': 5,
#    'Pain au Chocolat': 5,
#    'Croissant': 6,
#    'Custard Tart': 5,
#    'Granola Bar': 5,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 5,
#    'Anzac Biscuit': 7,
#    'Pain au Raisin': 5,
#    'Snickers Boost Ball': 5},
#   'breakfast': {'Sourdough Toast': 2,
#    'Ham Cheese Croissant': 1,
#    'Bacon Soda Farl': 2,
#    'Sausage Roll': 5,
#    'Organic Porridge': 3,
#    'Berry & Granola Parfait': 4},
#   'lunch': {'Ham & Cheese Toastie': 2,
#    'Caprese': 1,
#    'Chicken Bacon Wrap': 2,
#    'Chicken & Stuffing Bap': 3}},
#  '07/20/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Salted Caramel Brownie': 3,
#    'Oatmeal & Raisin Cookie': 2,
#    'Pain au Chocolat': 5,
#    'Croissant': 5,
#    'Mixed Berry Scone': 14,
#    'Custard Tart': 6,
#    'Granola Bar': 2,
#    'Blueberry Banana Loaf': 3,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 8,
#    'Snickers Boost Ball': 6,
#    'Pain au Raisin': 3},
#   'breakfast': {'Ham Cheese Croissant': 2,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 4,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Caprese': 3,
#    'Tuna Melt': 2,
#    'Chicken & Stuffing Bap': 2,
#    'Chicken Bacon Wrap': 1,
#    'Ham & Cheese Toastie': 3}},
#  '07/21/2019 00:00:00': {'bakedgoods': {'Cinnabun': 4,
#    'Salted Caramel Brownie': 6,
#    'Pain au Chocolat': 4,
#    'Croissant': 2,
#    'Mixed Berry Scone': 8,
#    'Custard Tart': 5,
#    'Oatmeal & Raisin Cookie': 2,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 4,
#    'Blueberry Banana Loaf': 1,
#    'Pain au Raisin': 4,
#    'Granola Bar': 5,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Ham Cheese Croissant': 2,
#    'Sausage Roll': 3,
#    'Berry & Granola Parfait': 1},
#   'lunch': {'Chicken Bacon Wrap': 1,
#    'Chicken & Stuffing Bap': 1,
#    'Ham & Cheese Toastie': 1}},
#  '07/22/2019 00:00:00': {'bakedgoods': {'Cinnabun': 4,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 4,
#    'Croissant': 7,
#    'Mixed Berry Scone': 16,
#    'Custard Tart': 4,
#    'Oatmeal & Raisin Cookie': 3,
#    'Apple & Pistachio Financier': 1,
#    'Anzac Biscuit': 7,
#    'Blueberry Banana Loaf': 3,
#    'Pain au Raisin': 6,
#    'Granola Bar': 6,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Ham Cheese Croissant': 2,
#    'Sausage Roll': 1,
#    'Organic Porridge': 6,
#    'Berry & Granola Parfait': 7},
#   'lunch': {'Caprese': 1,
#    'Ham & Cheese Toastie': 4,
#    'Tuna Melt': 1,
#    'Spring Vegan Wrap': 1,
#    'Chicken & Stuffing Bap': 1}},
#  '07/23/2019 00:00:00': {'bakedgoods': {'Cinnabun': 4,
#    'Salted Caramel Brownie': 1,
#    'Oatmeal & Raisin Cookie': 2,
#    'Pain au Chocolat': 4,
#    'Croissant': 2,
#    'Mixed Berry Scone': 9,
#    'Custard Tart': 6,
#    'Anzac Biscuit': 8,
#    'Blueberry Banana Loaf': 2,
#    'Apple & Pistachio Financier': 1,
#    'Pain au Raisin': 4,
#    'Granola Bar': 2,
#    'Snickers Boost Ball': 6},
#   'breakfast': {'Ham Cheese Croissant': 1,
#    'Sourdough Toast': 1,
#    'Sausage Roll': 4,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Tuna Melt': 2,
#    'Caprese': 2,
#    'Ham & Cheese Toastie': 3,
#    'Chicken Bacon Wrap': 3,
#    'Spring Vegan Wrap': 1,
#    'Chicken & Stuffing Bap': 1}},
#  '07/24/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 15,
#    'Cinnabun': 6,
#    'Salted Caramel Brownie': 5,
#    'Pain au Chocolat': 1,
#    'Croissant': 3,
#    'Custard Tart': 5,
#    'Oatmeal & Raisin Cookie': 4,
#    'Granola Bar': 5,
#    'Anzac Biscuit': 9,
#    'Snickers Boost Ball': 9,
#    'Blueberry Banana Loaf': 7,
#    'Apple & Pistachio Financier': 3,
#    'Pain au Raisin': 5},
#   'breakfast': {'Ham Cheese Croissant': 2,
#    'Sausage Roll': 5,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Caprese': 3,
#    'Spring Vegan Wrap': 1,
#    'Ham & Cheese Toastie': 1,
#    'Chicken Bacon Wrap': 2,
#    'Tuna Melt': 1}},
#  '07/25/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 19,
#    'Cinnabun': 6,
#    'Salted Caramel Brownie': 5,
#    'Pain au Chocolat': 4,
#    'Croissant': 5,
#    'Custard Tart': 6,
#    'Oatmeal & Raisin Cookie': 5,
#    'Granola Bar': 6,
#    'Blueberry Banana Loaf': 5,
#    'Apple & Pistachio Financier': 4,
#    'Anzac Biscuit': 8,
#    'Snickers Boost Ball': 4,
#    'Pain au Raisin': 5},
#   'breakfast': {'Sourdough Toast': 3,
#    'Bacon Soda Farl': 2,
#    'Sausage Roll': 4,
#    'Organic Porridge': 3,
#    'Berry & Granola Parfait': 4,
#    'Ham Cheese Croissant': 2},
#   'lunch': {'Spring Vegan Wrap': 2,
#    'Ham & Cheese Toastie': 1,
#    'Caprese': 2,
#    'Chicken Bacon Wrap': 5,
#    'Tuna Melt': 2,
#    'Chicken & Stuffing Bap': 4}},
#  '07/26/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Pain au Chocolat': 4,
#    'Croissant': 5,
#    'Salted Caramel Brownie': 1,
#    'Mixed Berry Scone': 20,
#    'Custard Tart': 6,
#    'Oatmeal & Raisin Cookie': 5,
#    'Apple & Pistachio Financier': 5,
#    'Anzac Biscuit': 8,
#    'Snickers Boost Ball': 8,
#    'Blueberry Banana Loaf': 5,
#    'Pain au Raisin': 4,
#    'Granola Bar': 7},
#   'breakfast': {'Ham Cheese Croissant': 5,
#    'Sourdough Toast': 1,
#    'Sausage Roll': 6,
#    'Organic Porridge': 2,
#    'Berry & Granola Parfait': 5},
#   'lunch': {'Spring Vegan Wrap': 2,
#    'Tuna Melt': 3,
#    'Caprese': 3,
#    'Ham & Cheese Toastie': 3,
#    'Chicken Bacon Wrap': 4,
#    'Chicken & Stuffing Bap': 3,
#    'Soup of the Day': 1}},
#  '07/27/2019 00:00:00': {'bakedgoods': {'Cinnabun': 5,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 4,
#    'Croissant': 4,
#    'Custard Tart': 3,
#    'Oatmeal & Raisin Cookie': 2,
#    'Granola Bar': 4,
#    'Blueberry Banana Loaf': 4,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 8,
#    'Snickers Boost Ball': 3,
#    'Mixed Berry Scone': 14,
#    'Pain au Raisin': 4},
#   'breakfast': {'Ham Cheese Croissant': 3,
#    'Sausage Roll': 3,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Ham & Cheese Toastie': 3,
#    'Caprese': 1,
#    'Chicken Bacon Wrap': 2,
#    'Tuna Melt': 1,
#    'Chicken & Stuffing Bap': 1}},
#  '07/28/2019 00:00:00': {'bakedgoods': {'Cinnabun': 3,
#    'Pain au Chocolat': 3,
#    'Salted Caramel Brownie': 2,
#    'Croissant': 2,
#    'Mixed Berry Scone': 12,
#    'Custard Tart': 2,
#    'Oatmeal & Raisin Cookie': 1,
#    'Blueberry Banana Loaf': 3,
#    'Anzac Biscuit': 6,
#    'Snickers Boost Ball': 6,
#    'Apple & Pistachio Financier': 1,
#    'Pain au Raisin': 2},
#   'breakfast': {'Bacon Soda Farl': 1,
#    'Sausage Roll': 2,
#    'Berry & Granola Parfait': 1,
#    'Ham Cheese Croissant': 1},
#   'lunch': {'Spring Vegan Wrap': 2,
#    'Caprese': 1,
#    'Tuna Melt': 1,
#    'Chicken Bacon Wrap': 1,
#    'Chicken & Stuffing Bap': 2}},
#  '07/29/2019 00:00:00': {'bakedgoods': {'Cinnabun': 5,
#    'Salted Caramel Brownie': 4,
#    'Pain au Chocolat': 1,
#    'Croissant': 4,
#    'Mixed Berry Scone': 12,
#    'Oatmeal & Raisin Cookie': 2,
#    'Custard Tart': 5,
#    'Apple & Pistachio Financier': 2,
#    'Anzac Biscuit': 9,
#    'Blueberry Banana Loaf': 2,
#    'Pain au Raisin': 4,
#    'Granola Bar': 3,
#    'Snickers Boost Ball': 4},
#   'breakfast': {'Sourdough Toast': 4,
#    'Ham Cheese Croissant': 2,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 4,
#    'Organic Porridge': 5,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Tuna Melt': 2,
#    'Caprese': 2,
#    'Chicken & Stuffing Bap': 2,
#    'Ham & Cheese Toastie': 2,
#    'Chicken Bacon Wrap': 2}},
#  '07/30/2019 00:00:00': {'bakedgoods': {'Mixed Berry Scone': 13,
#    'Cinnabun': 7,
#    'Salted Caramel Brownie': 3,
#    'Pain au Chocolat': 4,
#    'Croissant': 4,
#    'Custard Tart': 5,
#    'Oatmeal & Raisin Cookie': 4,
#    'Granola Bar': 5,
#    'Blueberry Banana Loaf': 6,
#    'Apple & Pistachio Financier': 2,
#    'Anzac Biscuit': 9,
#    'Snickers Boost Ball': 5,
#    'Pain au Raisin': 5},
#   'breakfast': {'Sourdough Toast': 4,
#    'Ham Cheese Croissant': 4,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 2,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 3},
#   'lunch': {'Caprese': 2,
#    'Ham & Cheese Toastie': 1,
#    'Chicken Bacon Wrap': 2,
#    'Chicken & Stuffing Bap': 1}},
#  '07/31/2019 00:00:00': {'bakedgoods': {'Cinnabun': 6,
#    'Salted Caramel Brownie': 3,
#    'Pain au Chocolat': 2,
#    'Croissant': 6,
#    'Mixed Berry Scone': 15,
#    'Custard Tart': 4,
#    'Oatmeal & Raisin Cookie': 5,
#    'Blueberry Banana Loaf': 6,
#    'Apple & Pistachio Financier': 3,
#    'Anzac Biscuit': 9,
#    'Snickers Boost Ball': 5,
#    'Pain au Raisin': 2,
#    'Granola Bar': 5},
#   'breakfast': {'Sourdough Toast': 2,
#    'Bacon Soda Farl': 1,
#    'Sausage Roll': 3,
#    'Organic Porridge': 4,
#    'Berry & Granola Parfait': 4,
#    'Ham Cheese Croissant': 3},
#   'lunch': {'Ham & Cheese Toastie': 4,
#    'Spring Wrap': 1,
#    'Caprese': 4,
#    'Chicken Bacon Wrap': 5,
#    'Tuna Melt': 2,
#    'Spring Vegan Wrap': 1,
#    'Chicken & Stuffing Bap': 2}}}

# %%
dailysales_df = pd.DataFrame(dailysales)

# %%
dailysales_df
# Out:
#                                           06/24/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 7, 'Salted Caramel Brownie': 4, '...
# breakfast   {'Ham Cheese Croissant': 3, 'Sourdough Toast':...
# lunch       {'Tuna Melt': 3, 'Caprese': 2, 'Ham & Cheese T...
#
#                                           06/25/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 6, 'Pain au Chocolat': 2, 'Croiss...
# breakfast   {'Sausage Roll': 2, 'Organic Porridge': 5, 'Be...
# lunch       {'Spring Vegan Wrap': 2, 'Ham & Cheese Toastie...
#
#                                           06/26/2019 00:00:00  \
# bakedgoods  {'Mixed Berry Scone': 15, 'Cinnabun': 4, 'Salt...
# breakfast   {'Sourdough Toast': 1, 'Sausage Roll': 5, 'Org...
# lunch       {'Caprese': 2, 'Ham & Cheese Toastie': 3, 'Tun...
#
#                                           06/27/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 6, 'Pain au Chocolat': 2, 'Croiss...
# breakfast   {'Ham Cheese Croissant': 4, 'Sausage Roll': 6,...
# lunch       {'Spring Vegan Wrap': 2, 'Tuna Melt': 2, 'Capr...
#
#                                           06/28/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 7, 'Salted Caramel Brownie': 2, '...
# breakfast   {'Sausage Roll': 6, 'Organic Porridge': 3, 'Be...
# lunch       {'Caprese': 4, 'Ham & Cheese Toastie': 4, 'Chi...
#
#                                           06/29/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 5, 'Pain au Chocolat': 1, 'Salted...
# breakfast   {'Berry & Granola Parfait': 2, 'Sausage Roll': 6}
# lunch       {'Spring Vegan Wrap': 3, 'Tuna Melt': 3, 'Ham ...
#
#                                           06/30/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 4, 'Pain au Chocolat': 4, 'Salted...
# breakfast   {'Ham Cheese Croissant': 3, 'Sausage Roll': 4,...
# lunch       {'Caprese': 2, 'Ham & Cheese Toastie': 2, 'Chi...
#
#                                           07/01/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 4, 'Oatmeal & Raisin Cookie': 4, ...
# breakfast   {'Ham Cheese Croissant': 2, 'Sourdough Toast':...
# lunch       {'Ham & Cheese Toastie': 4, 'Caprese': 1, 'Tun...
#
#                                           07/02/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 6, 'Salted Caramel Brownie': 5, '...
# breakfast   {'Ham Cheese Croissant': 3, 'Sausage Roll': 1,...
# lunch       {'Caprese': 3, 'Ham & Cheese Toastie': 1, 'Chi...
#
#                                           07/03/2019 00:00:00  ...  \
# bakedgoods  {'Mixed Berry Scone': 17, 'Cinnabun': 6, 'Pain...  ...
# breakfast   {'Sourdough Toast': 1, 'Bacon Soda Farl': 2, '...  ...
# lunch       {'Tuna Melt': 2, 'Ham & Cheese Toastie': 1, 'C...  ...
#
#                                           07/22/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 4, 'Pain au Chocolat': 3, 'Salted...
# breakfast   {'Ham Cheese Croissant': 2, 'Sausage Roll': 1,...
# lunch       {'Caprese': 1, 'Ham & Cheese Toastie': 4, 'Tun...
#
#                                           07/23/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 4, 'Salted Caramel Brownie': 1, '...
# breakfast   {'Ham Cheese Croissant': 1, 'Sourdough Toast':...
# lunch       {'Tuna Melt': 2, 'Caprese': 2, 'Ham & Cheese T...
#
#                                           07/24/2019 00:00:00  \
# bakedgoods  {'Mixed Berry Scone': 15, 'Cinnabun': 6, 'Salt...
# breakfast   {'Ham Cheese Croissant': 2, 'Sausage Roll': 5,...
# lunch       {'Caprese': 3, 'Spring Vegan Wrap': 1, 'Ham & ...
#
#                                           07/25/2019 00:00:00  \
# bakedgoods  {'Mixed Berry Scone': 19, 'Cinnabun': 6, 'Salt...
# breakfast   {'Sourdough Toast': 3, 'Bacon Soda Farl': 2, '...
# lunch       {'Spring Vegan Wrap': 2, 'Ham & Cheese Toastie...
#
#                                           07/26/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 6, 'Pain au Chocolat': 4, 'Croiss...
# breakfast   {'Ham Cheese Croissant': 5, 'Sourdough Toast':...
# lunch       {'Spring Vegan Wrap': 2, 'Tuna Melt': 3, 'Capr...
#
#                                           07/27/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 5, 'Pain au Chocolat': 3, 'Salted...
# breakfast   {'Ham Cheese Croissant': 3, 'Sausage Roll': 3,...
# lunch       {'Ham & Cheese Toastie': 3, 'Caprese': 1, 'Chi...
#
#                                           07/28/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 3, 'Pain au Chocolat': 3, 'Salted...
# breakfast   {'Bacon Soda Farl': 1, 'Sausage Roll': 2, 'Ber...
# lunch       {'Spring Vegan Wrap': 2, 'Caprese': 1, 'Tuna M...
#
#                                           07/29/2019 00:00:00  \
# bakedgoods  {'Cinnabun': 5, 'Salted Caramel Brownie': 4, '...
# breakfast   {'Sourdough Toast': 4, 'Ham Cheese Croissant':...
# lunch       {'Tuna Melt': 2, 'Caprese': 2, 'Chicken & Stuf...
#
#                                           07/30/2019 00:00:00  \
# bakedgoods  {'Mixed Berry Scone': 13, 'Cinnabun': 7, 'Salt...
# breakfast   {'Sourdough Toast': 4, 'Ham Cheese Croissant':...
# lunch       {'Caprese': 2, 'Ham & Cheese Toastie': 1, 'Chi...
#
#                                           07/31/2019 00:00:00
# bakedgoods  {'Cinnabun': 6, 'Salted Caramel Brownie': 3, '...
# breakfast   {'Sourdough Toast': 2, 'Bacon Soda Farl': 1, '...
# lunch       {'Ham & Cheese Toastie': 4, 'Spring Wrap': 1, ...
#
# [3 rows x 38 columns]

# %%
class SalesGrowth:
    def __init__(self, category, day, percentile):
        self.category = category
        self.day = day
        self.percentile = percentile
        
    def __iter__(self):
        yield self.category
        yield self.day
        yield self.percentile
        
    @classmethod
    def columns(cls):
        return['category', 'day', 'percentile']

# %%
class AllSalesGrowth:
    def __init__(self):
        self.lst = []
        
    def set_item(self, item):
        self.lst.append(item)
        
    def get_item(self, category, day):
        for i in range(len(self.lst)):
            if self.lst[i].category == category and self.lst[i].day == day:
                return self.lst[i]
        return False
    
    def get_percentile(self, category, day):
        for i in range(len(self.lst)):
            if self.lst[i].category == category and self.lst[i].day == day:
                    return self.lst[i].percentile
                
    @property
    def items(self):
        return pd.DataFrame(self.lst, columns=SalesGrowth.columns())

# %%
import datetime

# %%
growth_json = pd.read_json('data/percentile_change/SAS/{}_{}.json'.format(month, year))
growth_json
# Out:
#                0     1     2     3     4     5     6
# bakedgoods  22.2  18.7  17.8  14.5   6.1  22.8  24.5
# breakfast    5.2 -14.6   0.7  -4.5 -15.3  -5.2  17.1
# lunch       -7.1  -8.9  -5.6  -0.8 -10.9  28.9  78.4

# %%
growths = AllSalesGrowth()

for category in growth_json.index:
    for day in growth_json.columns:    
        percentile = growth_json.loc[category, day]
        growth = SalesGrowth(category, day, percentile)
        growths.set_item(growth)

# %%
growths.items
# Out:
#       category  day  percentile
# 0   bakedgoods    0        22.2
# 1   bakedgoods    1        18.7
# 2   bakedgoods    2        17.8
# 3   bakedgoods    3        14.5
# 4   bakedgoods    4         6.1
# 5   bakedgoods    5        22.8
# 6   bakedgoods    6        24.5
# 7    breakfast    0         5.2
# 8    breakfast    1       -14.6
# 9    breakfast    2         0.7
# 10   breakfast    3        -4.5
# 11   breakfast    4       -15.3
# 12   breakfast    5        -5.2
# 13   breakfast    6        17.1
# 14       lunch    0        -7.1
# 15       lunch    1        -8.9
# 16       lunch    2        -5.6
# 17       lunch    3        -0.8
# 18       lunch    4       -10.9
# 19       lunch    5        28.9
# 20       lunch    6        78.4

# %%
weathers_df = pd.DataFrame(pd.read_json('data/historical_weather/07-01-2018_10-19-2020.json'))
weathers_df
# Out:
#             temp  weather_id
# 2018-07-01  20.9       804.0
# 2018-07-02  21.0       800.0
# 2018-07-03  19.6       801.0
# 2018-07-04  23.1       801.0
# 2018-07-05  19.1       803.0
# ...          ...         ...
# 2020-10-16  10.4       803.0
# 2020-10-17  10.2       803.0
# 2020-10-18  11.8       803.0
# 2020-10-19  12.0       500.0
# 2020-10-20   0.0         NaN
#
# [843 rows x 2 columns]

# %%
class Weather:
    def __init__(self, date, temp, weather):
        self.date = date
        self.temp = temp
        self.weather = weather
        
    def __iter__(self):
        yield self.date
        yield self.temp
        yield self.weather
        
    @classmethod
    def columns(cls):
        return['date', 'temp', 'weather']

# %%
class AllWeather:
    def __init__(self):
        self.arr = {}
        
    def set_item(self, item):
        self.arr[item.date] = item
        
    def get_item(self, date):
        if date in self.arr:
            return self.arr[date]
        else:
            return False
    
    @property
    def items(self):
        return pd.DataFrame(self.arr.values(), columns=Weather.columns())

# %%
weathers = AllWeather()

for index in weathers_df.index:
    date = index.strftime('%m/%d/%Y')
    temp = weathers_df.loc[index, 'temp']
    weather_id = weathers_df.loc[index, 'weather_id']
    weather = Weather(date, temp, weather_id)
    weathers.set_item(weather)

# %%
weathers.items
# Out:
#            date  temp  weather
# 0    07/01/2018  20.9    804.0
# 1    07/02/2018  21.0    800.0
# 2    07/03/2018  19.6    801.0
# 3    07/04/2018  23.1    801.0
# 4    07/05/2018  19.1    803.0
# ..          ...   ...      ...
# 838  10/16/2020  10.4    803.0
# 839  10/17/2020  10.2    803.0
# 840  10/18/2020  11.8    803.0
# 841  10/19/2020  12.0    500.0
# 842  10/20/2020   0.0      NaN
#
# [843 rows x 3 columns]

# %%
class Date:
    def __init__(self, date):
        self.date = date
        self.dayofweek = pd.Timestamp(pd.to_datetime(date)).dayofweek
        self.weeknum = pd.to_datetime(date).strftime("%W")
        self.day = pd.to_datetime(date).day
        self.month = pd.to_datetime(date).month
        self.year = pd.to_datetime(date).year
        self.holiday = 0
        
    def __iter__(self):
        yield self.dayofweek
        yield self.weeknum
        yield self.day
        yield self.month
        yield self.year
        yield self.holiday
        
    @classmethod
    def columns(cls):
        return['dayofweek', 'weeknum', 'day', 'month', 'year', 'holiday']
        
class Calendar:
    def __init__(self):
        self.arr = {}
        
    def set_date(self, item):
        self.arr[item.date] = item
        
    def get_date(self, date):
        if date in self.arr:
            return self.arr[date]
        else:
            return False
        
    @property
    def items(self):
        return pd.DataFrame(self.arr.values(), columns=Date.columns())

# %%
class Product:    
    def __init__(self, id, name, category):
        self.id = id
        self.name = name
        self.category = category
            
    def __iter__(self):
        yield self.id
        yield self.name
        yield self.category
    
    @classmethod
    def columns(cls):
        return ['id', 'name', 'category']
        
    
class Sales:
    def __init__(self, soldnum, date=None, product=None, weather=None, growth=None):
        self.product = product
        self.date = date
        self.soldnum = soldnum
        self.prevdaysales = []
        self.weather = weather
        self.growth = growth
        
    def set_prevdaysales(self, quantity):
        self.prevdaysales.append(quantity)
        
    def __iter__(self):
        yield self.product.id
        yield self.product.name
        yield self.product.category
        yield self.date.date
        yield self.date.dayofweek
        yield self.date.weeknum
        yield self.date.year
        yield self.date.holiday
        yield self.soldnum
        yield self.growth.percentile
        for i in range(7):
            try:
                prevsales = self.prevdaysales[i]
            except:
                prevsales = 'null'
            yield prevsales
            
        yield self.weather.temp
        yield self.weather.weather
        
    @classmethod
    def columns(cls):
        return['id', 'name', 'category', 'date', 'dayofweek', 'weeknum', 'year',
               'holiday', 'soldnum', 'growth', 'prevdaysales1', 'prevdaysales2', 'prevdaysales3', 
               'prevdaysales4', 'prevdaysales5', 'prevdaysales6', 'prevdaysales7', 'temp', 'weather']

# %%
class AllProduct:
    def __init__(self):
        self.arr = {}
        
    def set_item(self, item):
        self.arr[item.name] = item
        
    def get_item(self, name):
        if name in self.arr:
            return self.arr[name]
        else:
            return False
        
    def delete(self, name):
        del self.arr[name]
        
    @property
    def items(self):
        return pd.DataFrame(self.arr.values(), columns=Product.columns())

# %%
class Trainingset:
    def __init__(self):
        self.arr = {}
        
    def set_item(self, item):
        key = '{}, {}'.format(item.date.date, item.product.name)
        self.arr[key] = item
        
    def get_item(self, name, date):
        key = '{}, {}'.format(date, name)
        if key in self.arr:
            return self.arr[key]
        else:
            return False
    
    def delete(self, name, date):
        key = '{}, {}'.format(date, name)
        del self.arr[key]
        
    @property
    def items(self):
        return pd.DataFrame(self.arr.values(), columns=Sales.columns())

# %%
url = 'https://holidays.abstractapi.com/v1/'
params = {
    'api_key': '02a0112703a34f5abb1ab898b4f8125a',
    'country': 'IE',
    'year': str(year)
}

# %%
result = requests.get(url=url, params=params)
result_json = result.json()
df_holidays = pd.DataFrame(result_json)
df_holidays
# Out:
#                     name name_local language description country location  \
# 0         New Year's Day                                      IE  Ireland
# 1      St. Patrick's Day                                      IE  Ireland
# 2          March Equinox                                      IE  Ireland
# 3            Good Friday                                      IE  Ireland
# 4                 Easter                                      IE  Ireland
# 5          Easter Monday                                      IE  Ireland
# 6                May Day                                      IE  Ireland
# 7      June Bank Holiday                                      IE  Ireland
# 8          June Solstice                                      IE  Ireland
# 9    August Bank Holiday                                      IE  Ireland
# 10     September Equinox                                      IE  Ireland
# 11  October Bank Holiday                                      IE  Ireland
# 12     December Solstice                                      IE  Ireland
# 13         Christmas Eve                                      IE  Ireland
# 14         Christmas Day                                      IE  Ireland
# 15     St. Stephen's Day                                      IE  Ireland
# 16        New Year's Eve                                      IE  Ireland
#
#           type        date date_year date_month date_day   week_day
# 0     National  01/01/2019      2019         01       01    Tuesday
# 1     National  03/17/2019      2019         03       17     Sunday
# 2     Seasonal  03/20/2019      2019         03       20  Wednesday
# 3   Observance  04/19/2019      2019         04       19     Friday
# 4   Observance  04/21/2019      2019         04       21     Sunday
# 5     National  04/22/2019      2019         04       22     Monday
# 6     National  05/06/2019      2019         05       06     Monday
# 7     National  06/03/2019      2019         06       03     Monday
# 8     Seasonal  06/21/2019      2019         06       21     Friday
# 9     National  08/05/2019      2019         08       05     Monday
# 10    Seasonal  09/23/2019      2019         09       23     Monday
# 11    National  10/28/2019      2019         10       28     Monday
# 12    Seasonal  12/22/2019      2019         12       22     Sunday
# 13  Observance  12/24/2019      2019         12       24    Tuesday
# 14    National  12/25/2019      2019         12       25  Wednesday
# 15    National  12/26/2019      2019         12       26   Thursday
# 16  Observance  12/31/2019      2019         12       31    Tuesday

# %%
import hashlib
m = hashlib.md5()

# %%
trset = Trainingset()
products = AllProduct()
calendar = Calendar()
dt_ = None
holiday = 0

products_json = pd.read_json('data/products/products.json')
products_df = pd.DataFrame(products_json)

for index in products_df.index:
    id = products_df.loc[index, 'id']
    name = products_df.loc[index, 'name']
    category = products_df.loc[index, 'category']
    product = Product(id, name, category)
    products.set_item(product)

# if all categories are True, that means the shop
# sold none of products, which means the shop were closed
closed = {'bakedgoods': False, 'lunch': False, 'breakfast': False} 

for date in dailysales_df.columns:
    dt_ = pd.to_datetime(date).strftime("%m/%d/%Y")
    dt = Date(dt_)

    for index in df_holidays.index:
        if df_holidays.loc[index, 'date'] == dt_:
            dt.holiday = 1
    
    calendar.set_date(dt)
    
    for category in dailysales_df.index:
        sales = dailysales_df.loc[category, date]
        if sales == {}:
            closed[category] = True
            
        for itemname, sales in sales.items():
            product = products.get_item(itemname)
            weather = weathers.get_item(dt_)
            
            if product == False:
                m.update(str(itemname).encode('utf-8'))
                id = str(int(m.hexdigest(), 16))[0:3]
                product = Product(id, itemname, category)
                products.set_item(product)
            
            if weather == False:
                weather = Weather(dt_, 'null', 'null')
                weathers.set_item(weather)
            
            dateinfo = calendar.get_date(dt_)
            
            growth = growths.get_item(product.category, dateinfo.dayofweek)
            sales = Sales(sales, dateinfo, product, weather, growth)
            trset.set_item(sales)

    if closed['bakedgoods'] and closed['lunch'] and closed['breakfast']:
        # if shops seems closed, do nothing
        closed['bakedgoods'] = False
        closed['lunch'] = False
        closed['breakfast'] = False
        continue
    else:
        # if the shop is open but seems the product sales is 0,
        # add the sales 0 into the training data
        for index in products.items.index:
            itemname = products.items.loc[index, 'name']
            item = trset.get_item(itemname, dt_)
            if item is False:
                dateinfo = calendar.get_date(dt_)
                product = products.get_item(itemname)
                weather = weathers.get_item(dt_)
                
                if weather == False:
                    weather = Weather(dt_, 'null', 'null')
                    weathers.set_item(weather)
                    
                growth = growths.get_item(product.category, dateinfo.dayofweek)
                sales = Sales(0, dateinfo, product, weather, growth)
                trset.set_item(sales)

# %%
os.remove("data/products/products.json")
products.items.to_json(r'data/products/products.json')

# %%
trset.items
# Out:
#        id                     name    category        date  dayofweek weeknum  \
# 0     209                 Cinnabun  bakedgoods  06/24/2019          0      25
# 1     288   Salted Caramel Brownie  bakedgoods  06/24/2019          0      25
# 2     157  Oatmeal & Raisin Cookie  bakedgoods  06/24/2019          0      25
# 3     245         Pain au Chocolat  bakedgoods  06/24/2019          0      25
# 4     564                Croissant  bakedgoods  06/24/2019          0      25
# ...   ...                      ...         ...         ...        ...     ...
# 2418  416         Coconut Snowball  bakedgoods  07/31/2019          2      30
# 2419  276          Turkey Sandwich       lunch  07/31/2019          2      30
# 2420  204         Cheese Croissant   breakfast  07/31/2019          2      30
# 2421  320       Carrot Cake Muffin  bakedgoods  07/31/2019          2      30
# 2422  233         Chicken Stuffing       lunch  07/31/2019          2      30
#
#       year  holiday  soldnum  growth prevdaysales1 prevdaysales2  \
# 0     2019        0        7    22.2          null          null
# 1     2019        0        4    22.2          null          null
# 2     2019        0        4    22.2          null          null
# 3     2019        0        4    22.2          null          null
# 4     2019        0        3    22.2          null          null
# ...    ...      ...      ...     ...           ...           ...
# 2418  2019        0        0    17.8          null          null
# 2419  2019        0        0    -5.6          null          null
# 2420  2019        0        0     0.7          null          null
# 2421  2019        0        0    17.8          null          null
# 2422  2019        0        0    -5.6          null          null
#
#      prevdaysales3 prevdaysales4 prevdaysales5 prevdaysales6 prevdaysales7  \
# 0             null          null          null          null          null
# 1             null          null          null          null          null
# 2             null          null          null          null          null
# 3             null          null          null          null          null
# 4             null          null          null          null          null
# ...            ...           ...           ...           ...           ...
# 2418          null          null          null          null          null
# 2419          null          null          null          null          null
# 2420          null          null          null          null          null
# 2421          null          null          null          null          null
# 2422          null          null          null          null          null
#
#       temp  weather
# 0     16.8    803.0
# 1     16.8    803.0
# 2     16.8    803.0
# 3     16.8    803.0
# 4     16.8    803.0
# ...    ...      ...
# 2418  18.0    803.0
# 2419  18.0    803.0
# 2420  18.0    803.0
# 2421  18.0    803.0
# 2422  18.0    803.0
#
# [2423 rows x 19 columns]

# %%
products.items
# Out:
#      id                name    category
# 0   226    Almond Financier  bakedgoods
# 1   296   Mixed Berry Scone  bakedgoods
# 2   328  Cheesecake Brownie  bakedgoods
# 3   335             Cruffin  bakedgoods
# 4   337     Lemon Financier  bakedgoods
# ..  ...                 ...         ...
# 59  261           Tuna Melt       lunch
# 60  667   Spring Vegan Wrap       lunch
# 61  233    Chicken Stuffing       lunch
# 62  267         Spring Wrap       lunch
# 63  317     Bacon Soda Farl   breakfast
#
# [64 rows x 3 columns]

# %%
from datetime import datetime, timedelta

# %%
for index in trset.items.index:
    count = 0
    currentitem = trset.get_item(trset.items.loc[index, 'name'], trset.items.loc[index, 'date'])
    currentdt = pd.to_datetime(currentitem.date.date)
    name = currentitem.product.name
    
    while len(currentitem.prevdaysales) < 7:
        if count < -20:
            break
        count -= 1
        
        prevdt = currentdt + timedelta(days=count)
        prevdt = prevdt.strftime("%m/%d/%Y")
        previtem = trset.get_item(name, prevdt)
        if previtem is not False:
            currentitem.set_prevdaysales(previtem.soldnum)
        else:
            continue
    count = 0

# %%
trset.items

# %%
train = Trainingset()

for key in trset.arr:
    item = trset.arr[key]
    if item.prevdaysales == [0, 0, 0, 0, 0, 0, 0] or len(item.prevdaysales) < 7:
        continue
    if item.weather.weather == 'null' or item.weather.temp == 'null':
        continue
    else:
        train.set_item(item)

# %%
train.items

# %%
train.items.to_json(r'data/training_set/{}_{}.json'.format(month, year))
